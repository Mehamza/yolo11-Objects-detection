# %%
# !pip install ultralytics opencv-python numpy
# Out:
# Requirement already satisfied: ultralytics in /home/lenovo/.local/lib/python3.8/site-packages (8.3.35)
# Requirement already satisfied: opencv-python in /home/lenovo/.local/lib/python3.8/site-packages (4.10.0.84)
# Requirement already satisfied: numpy in /home/lenovo/.local/lib/python3.8/site-packages (1.24.4)
# Requirement already satisfied: pillow>=7.1.2 in /home/lenovo/.local/lib/python3.8/site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: requests>=2.23.0 in /home/lenovo/.local/lib/python3.8/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from ultralytics) (5.5.1)
# Requirement already satisfied: pandas>=1.1.4 in /home/lenovo/.local/lib/python3.8/site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/lenovo/.local/lib/python3.8/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: tqdm>=4.64.0 in /home/lenovo/.local/lib/python3.8/site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: torchvision>=0.9.0 in /home/lenovo/.local/lib/python3.8/site-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: seaborn>=0.11.0 in /home/lenovo/.local/lib/python3.8/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: torch>=1.8.0 in /home/lenovo/.local/lib/python3.8/site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (5.4.1)
# Requirement already satisfied: py-cpuinfo in /home/lenovo/.local/lib/python3.8/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/lenovo/.local/lib/python3.8/site-packages (from ultralytics) (2.0.12)
# Requirement already satisfied: scipy>=1.4.1 in /home/lenovo/.local/lib/python3.8/site-packages (from ultralytics) (1.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/lenovo/.local/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.23.0->ultralytics) (1.25.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.23.0->ultralytics) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.23.0->ultralytics) (2019.11.28)
# Requirement already satisfied: tzdata>=2022.1 in /home/lenovo/.local/lib/python3.8/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/lenovo/.local/lib/python3.8/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lenovo/.local/lib/python3.8/site-packages (from pandas>=1.1.4->ultralytics) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/lenovo/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/lenovo/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.4.6)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lenovo/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lenovo/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/lenovo/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (5.7.1)
# Requirement already satisfied: cycler>=0.10 in /home/lenovo/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: fsspec in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: networkx in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: triton==3.0.0; platform_system == "Linux" and platform_machine == "x86_64" and python_version < "3.13" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (3.0.0)
# Requirement already satisfied: jinja2 in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch>=1.8.0->ultralytics) (3.0.12)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (2.20.5)
# Requirement already satisfied: sympy in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64" in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/lenovo/.local/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.4->ultralytics) (1.14.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/lenovo/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib>=3.3.0->ultralytics) (3.8.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/lenovo/.local/lib/python3.8/site-packages (from nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/lenovo/.local/lib/python3.8/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/lenovo/.local/lib/python3.8/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
import cv2
from ultralytics import YOLO
import datetime

# Load the YOLO11m model
model = YOLO('yolo11m.pt') 

# Video source
video_path = "Input_Video.mp4"
cap = cv2.VideoCapture(video_path)

# Class IDs for vehicles in the COCO dataset
vehicle_classes = [2, 3, 5, 7]  # Car, Motorcycle, Bus, Truck

# Map class IDs to vehicle types
vehicle_labels = {
    2: "Car",
    3: "Motorcycle",
    5: "Bus",
    7: "Truck"
}

# Get the video frame width and height for saving the output video
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))


current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S") #I used datatime library just for naming output video
output_video_path = f'Output_video_{current_time}.mp4'


fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4 format
out = cv2.VideoWriter(output_video_path, fourcc, 30, (frame_width, frame_height))
total_cars = 0
while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame, stream=True)

    # Process detections
    for result in results:
        for box in result.boxes:
            classId = int(box.cls[0])  
            confidence = float(box.conf[0]) 
            x1, y1, x2, y2 = map(int, box.xyxy[0])

            # Check if the detected object is a vehicle
            if classId in vehicle_classes:
                vehicle_type = vehicle_labels.get(classId, "Unknown")
                
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
                label = f"{vehicle_type} ({confidence:.2f})"
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

    # Write the frame to the output video
    out.write(frame)

    # Show the frame
    cv2.imshow("Vehicle Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


cap.release()
out.release()  
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 persons, 14 cars, 4 buss, 409.7ms
# Speed: 30.5ms preprocess, 409.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons,
6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 4 buss, 1 truck, 379.8ms
# Speed: 6.5ms preprocess, 379.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 4 buss, 1 truck, 396.5ms
# Speed: 4.5ms preprocess, 396.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 4 buss, 1 truck, 367.6ms
# Speed: 35.4ms preprocess, 367.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 4 buss, 1 truck, 374.2ms
# Speed: 9.0ms preprocess, 374.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 4 buss, 368.7ms
# Speed: 2.8ms preprocess, 368.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 4 buss, 398.5ms
# Speed: 14.7ms preprocess, 398.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 4 buss, 383.0ms
# Speed: 2.8ms preprocess, 383.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 4 buss, 391.6ms
# Speed: 3.2ms preprocess, 391.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 4 buss, 379.3ms
# Speed: 9.1ms preprocess, 379.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 4 buss, 438.6ms
# Speed: 10.6ms preprocess, 438.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 5 buss, 423.8ms
# Speed: 10.0ms preprocess, 423.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 4 buss, 445.6ms
# Speed: 4.6ms preprocess, 445.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 4 buss, 435.3ms
# Speed: 3.1ms preprocess, 435.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 4 buss, 448.5ms
# Speed: 3.8ms preprocess, 448.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 4 buss, 439.7ms
# Speed: 8.4ms preprocess, 439.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 4 buss, 384.0ms
# Speed: 9.2ms preprocess, 384.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 40>()
#      45 results = model(frame, stream=True)
#      47 # Process detections
# ---> 48 for result in results:
#      49     for box in result.boxes:
#      50         cls = int(box.cls[0])  # Class ID
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~/.local/lib/python3.8/site-packages/ultralytics/engine/predictor.py:259, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     257 # Inference
#     258 with profilers[1]:
# --> 259     preds = self.inference(im, *args, **kwargs)
#     260     if self.args.embed:
#     261         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/.local/lib/python3.8/site-packages/ultralytics/engine/predictor.py:143, in BasePredictor.inference(self, im, *args, **kwargs)
#     137 """Runs inference on a given image using the specified model and arguments."""
#     138 visualize = (
#     139     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     140     if self.args.visualize and (not self.source_type.tensor)
#     141     else False
#     142 )
# --> 143 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.local/lib/python3.8/site-packages/ultralytics/nn/autobackend.py:526, in AutoBackend.forward(self, im, augment, visualize, embed)
#     524 # PyTorch
#     525 if self.pt or self.nn_module:
# --> 526     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     528 # TorchScript
#     529 elif self.jit:
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.local/lib/python3.8/site-packages/ultralytics/nn/tasks.py:112, in BaseModel.forward(self, x, *args, **kwargs)
#     110 if isinstance(x, dict):  # for cases of training and validating while training.
#     111     return self.loss(x, *args, **kwargs)
# --> 112 return self.predict(x, *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/ultralytics/nn/tasks.py:130, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     128 if augment:
#     129     return self._predict_augment(x)
# --> 130 return self._predict_once(x, profile, visualize, embed)
#
# File ~/.local/lib/python3.8/site-packages/ultralytics/nn/tasks.py:151, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     149 if profile:
#     150     self._profile_one_layer(m, x, dt)
# --> 151 x = m(x)  # run
#     152 y.append(x if m.i in self.save else None)  # save output
#     153 if visualize:
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.local/lib/python3.8/site-packages/ultralytics/nn/modules/block.py:238, in C2f.forward(self, x)
#     236 """Forward pass through C2f layer."""
#     237 y = list(self.cv1(x).chunk(2, 1))
# --> 238 y.extend(m(y[-1]) for m in self.m)
#     239 return self.cv2(torch.cat(y, 1))
#
# File ~/.local/lib/python3.8/site-packages/ultralytics/nn/modules/block.py:238, in <genexpr>(.0)
#     236 """Forward pass through C2f layer."""
#     237 y = list(self.cv1(x).chunk(2, 1))
# --> 238 y.extend(m(y[-1]) for m in self.m)
#     239 return self.cv2(torch.cat(y, 1))
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.local/lib/python3.8/site-packages/ultralytics/nn/modules/block.py:263, in C3.forward(self, x)
#     261 def forward(self, x):
#     262     """Forward pass through the CSP bottleneck with 2 convolutions."""
# --> 263     return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), 1))
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.local/lib/python3.8/site-packages/ultralytics/nn/modules/block.py:347, in Bottleneck.forward(self, x)
#     345 def forward(self, x):
#     346     """Applies the YOLO FPN to input data."""
# --> 347     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.local/lib/python3.8/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/conv.py:458, in Conv2d.forward(self, input)
#     457 def forward(self, input: Tensor) -> Tensor:
# --> 458     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/conv.py:454, in Conv2d._conv_forward(self, input, weight, bias)
#     450 if self.padding_mode != 'zeros':
#     451     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     452                     weight, bias, self.stride,
#     453                     _pair(0), self.dilation, self.groups)
# --> 454 return F.conv2d(input, weight, bias, self.stride,
#     455                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
